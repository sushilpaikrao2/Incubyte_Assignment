# %%
# importing necessary libraries
import mysql.connector
import pandas as pd

# %%
# connecting mysql server
database = mysql.connector.connect(host="localhost",user="root",passwd= "root1",database="project")
cursor = database.cursor()

# %%
Customer_df=pd.read_sql('SELECT * FROM patient1', con=database)

# %%
Customer_df
# Out:
#     Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0           111      samiksha  2021-06-10          2022-06-10            MVD
# 1           123        Akshay  2021-09-01          2022-09-02            MVD
# 2           345        Sushil  2021-08-05          2022-08-05            CSD
# 3           432         pooja  2021-08-06          2022-08-06            CSD
# 4           456        Shital  2021-09-05          2022-10-05            MVD
# 5           541        Amrish  2021-05-07          2022-05-07            MVD
# 6           567         Rakhi  2021-10-11          2022-10-11            MVD
# 7           653         Arjun  2021-02-09          2022-07-10            MVD
# 8           678        Chetna  2021-10-11          2022-10-11            CSD
# 9           753          asho  2021-05-08          2022-05-08            MVD
# 10          765         kajol  2021-02-09          2022-02-09            MVD
# ...

# %%
#store data on Local disk
Customer_df= Customer_df.to_csv('C:/Users/net comm15/Desktop/Incubyte_assessment/Customer_df.csv')

# %%
#fetching country wise data
Ind_df=pd.read_sql("SELECT * FROM patient1 where Country='IND'",con=database).to_csv('C:/Users/net comm15/Desktop/Incubyte_assessment/India_data.csv')
USA_df=pd.read_sql("SELECT * FROM patient1 where Country='USA'",con=database).to_csv('C:/Users/net comm15/Desktop/Incubyte_assessment/USA_data.csv')
UK_df=pd.read_sql("SELECT * FROM patient1 where Country='UK'",con=database).to_csv('C:/Users/net comm15/Desktop/Incubyte_assessment/UK_data.csv')
NYC_df=pd.read_sql("SELECT * FROM patient1 where Country='NYC'",con=database).to_csv('C:/Users/net comm15/Desktop/Incubyte_assessment/NYC_data.csv')
